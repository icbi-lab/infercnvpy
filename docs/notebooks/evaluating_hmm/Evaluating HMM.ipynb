# %% [markdown]
# # Evaluating InferCNV-Py HMM

# %%
from evaluation import *

# %% [markdown]
# The InferCNV-R wiki has a page on 'Additional InferCNV examples'. In this notebook we compare the output of InferCNV-R and InferCNV-Py on these examples. We do so by first comparing the HMMs only, taking the output of InferCNV-R just before the HMM step. We also look at the output from InferCNV-Py apart from InferCNV-R.

# %% [markdown]
# # Quickstart (oligodendoglioma)

# %%
quickstart_dir = '/Users/kasperrasmussen/documents/GitHub/kasper_cnv/infercnv_outputs/quickstart_h3_2'
evaluate_example(quickstart_dir, reference_cat =["Oligodendrocytes (non-malignant)", "Microglia/Macrophage"])
# Out:
# ... storing 'cell_type' as categorical
# A) Plot of InferCNV-R at stage 15 before it applies HMM:
# ... storing 'cell_type' as categorical
# B) Plot of InferCNV-R at stage 17 after it has applied HMM:
# ... storing 'cell_type' as categorical
# C) Plot of InferCNV-Py HMM applied to (A), should look similar to (B):
#   0%|          | 0/1 [00:00<?, ?it/s]
# ... storing 'cell_type' as categorical
# D) Taking InferCNV-R output at early stage 3 (before log-normalization), and using InferCNV-Py for the rest of the pipeline with windowing step-size 10 before HMM:
# ... storing 'cell_type' as categorical
# E) Applying InferCNV-Py HMM to (D)

# %% [markdown]
# # Melanoma

# %%
melanoma_partial_dir = '/Users/kasperrasmussen/documents/GitHub/kasper_cnv/data/inferCNV_examples/melanoma/melanoma_partial/output_dir'
evaluate_example(melanoma_partial_dir, reference_cat =["Endothelial", "NK", "Macrophage", "B", "T", "CAF"], step_size=10)
# Out:
# ... storing 'cell_type' as categorical
# A) Plot of InferCNV-R at stage 15 before it applies HMM:
# ... storing 'cell_type' as categorical
# B) Plot of InferCNV-R at stage 17 after it has applied HMM:
# ... storing 'cell_type' as categorical
# C) Plot of InferCNV-Py HMM applied to (A), should look similar to (B):
#   0%|          | 0/1 [00:00<?, ?it/s]
# ... storing 'cell_type' as categorical
# D) Taking InferCNV-R output at early stage 3 (before log-normalization), and using InferCNV-Py for the rest of the pipeline with windowing step-size 10 before HMM:
# ... storing 'cell_type' as categorical
# E) Applying InferCNV-Py HMM to (D)

# %% [markdown]
# # Pediatric midline glioma

# %%
pediatric_dir = '/Users/kasperrasmussen/documents/GitHub/kasper_cnv/data/inferCNV_examples/pediatric_midline_gliomas/pediatric_midline_gliomas_partial/output_dir'
evaluate_example(pediatric_dir, reference_cat = ["Oligodendrocyte", "Immune cell"])
# Out:
# ... storing 'cell_type' as categorical
# A) Plot of InferCNV-R at stage 15 before it applies HMM:
# ... storing 'cell_type' as categorical
# B) Plot of InferCNV-R at stage 17 after it has applied HMM:
# ... storing 'cell_type' as categorical
# C) Plot of InferCNV-Py HMM applied to (A), should look similar to (B):
